# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil8767/ML-projects/blob/main/housePricePrediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# House price prediction

# %%
# !git clone https://github.com/Nikhil18767/ML-projects.git
cd ML-projects
# Out:
#   File "/tmp/ipykernel_3855/3182280803.py", line 2
#     cd ML-projects
#        ^
# SyntaxError: invalid syntax

# %%
git remote add origin https://github.com/Nikhil8767/ML-projects.git
# Out:
#   File "/tmp/ipykernel_3855/912600030.py", line 1
#     git remote add origin https://github.com/Nikhil8767/ML-projects.git
#         ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/Nikhil18767/ML-projects.git
# Out:
# Cloning into 'ML-projects'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd ML-projects
# Out:
# [Errno 2] No such file or directory: 'ML-projects'
# /content

# %%
# !git clone https://github.com/Nikhil18767/ML-projects.git
# Out:
# Cloning into 'ML-projects'...
# fatal: could not read Username for 'https://github.com': No such device or address
