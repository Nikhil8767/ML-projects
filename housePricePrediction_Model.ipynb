# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil8767/ML-projects/blob/main/housePricePrediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# House price prediction

# %%
import pandas as pd

data = {
    "area": [1000, 1500, 1800, 2400, 3000],
    "bedrooms": [2, 3, 3, 4, 4],
    "age": [10, 8, 6, 5, 2],
    "price": [300000, 400000, 450000, 600000, 700000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    area  bedrooms  age   price
# 0  1000         2   10  300000
# 1  1500         3    8  400000
# 2  1800         3    6  450000
# 3  2400         4    5  600000
# 4  3000         4    2  700000
